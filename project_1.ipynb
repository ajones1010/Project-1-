# %%
# Dependencies 
import pandas as pd
import matplotlib as plt
from pathlib import Path
import numpy as np
# plt.style.use("bmh")
import matplotlib.pyplot as plt

# %%
# File to Load
file = Path("../Resources/U.S._Chronic_Disease_Indicators.csv")

# %%
# Read U.S chronic desease data File and store into Pandas DataFrame
chronic_df = pd.read_csv(file, low_memory=True)

# Data Frame chronic disease, 5 first rows 
chronic_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 0       2019     2019           GA      Georgia      BRFSS     Disability
# 1       2019     2019           GU         Guam      BRFSS      Arthritis
# 2       2019     2019           GU         Guam      BRFSS   Immunization
# 3       2019     2019           ME        Maine      BRFSS       Diabetes
# 4       2019     2019           NV       Nevada       NVSS  Health Status
#
#                              Question  Response DataValueUnit  \
# 0          Adults with any disability       NaN             %
# 1              Arthritis among adults       NaN             %
# 2  Influenza vaccination among adults       NaN             %
# 3               Diabetes among adults       NaN             %
# 4            Life expectancy at birth       NaN         Years
#
#       DataValueType  ...  TopicID  QuestionID ResponseID DataValueTypeID  \
# 0  Crude Prevalence  ...      DIS       DIS01        NaN         CRDPREV
# 1  Crude Prevalence  ...      ART       ART01        NaN         CRDPREV
# 2  Crude Prevalence  ...      IMM       IMM01        NaN         CRDPREV
# 3  Crude Prevalence  ...      DIA       DIA01        NaN         CRDPREV
# 4            Number  ...      HEA       HEA06        NaN            NMBR
#
#    StratificationCategoryID1  StratificationID1 StratificationCategoryID2  \
# 0                        AGE             AGE65P                       NaN
# 1                        SEX               SEXF                       NaN
# 2                        SEX               SEXM                       NaN
# 3                        SEX               SEXM                       NaN
# 4                    OVERALL                OVR                       NaN
#
#   StratificationID2  StratificationCategoryID3  StratificationID3
# 0               NaN                        NaN                NaN
# 1               NaN                        NaN                NaN
# 2               NaN                        NaN                NaN
# 3               NaN                        NaN                NaN
# 4               NaN                        NaN                NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# #Cleaning data

# %%
# Exploring to see all our columns 
chronic_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DataValueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'Geolocation', 'LocationID', 'TopicID', 'QuestionID', 'ResponseID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
# Exploring the whole data 
chronic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311745 entries, 0 to 311744
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  311745 non-null  int64
#  1   YearEnd                    311745 non-null  int64
#  2   LocationAbbr               311745 non-null  object
#  3   LocationDesc               311745 non-null  object
#  4   DataSource                 311745 non-null  object
#  5   Topic                      311745 non-null  object
#  6   Question                   311745 non-null  object
#  7   Response                   0 non-null       float64
#  8   DataValueUnit              311745 non-null  object
#  9   DataValueType              311745 non-null  object
#  10  DataValue                  210684 non-null  float64
#  11  DataValueAlt               210684 non-null  float64
#  12  DataValueFootnoteSymbol    102758 non-null  object
#  13  DataValueFootnote          102758 non-null  object
#  14  LowConfidenceLimit         190373 non-null  float64
#  15  HighConfidenceLimit        190378 non-null  float64
#  16  StratificationCategory1    311745 non-null  object
#  17  Stratification1            311745 non-null  object
#  18  StratificationCategory2    0 non-null       float64
#  19  Stratification2            0 non-null       float64
#  20  StratificationCategory3    0 non-null       float64
#  21  Stratification3            0 non-null       float64
#  22  Geolocation                305936 non-null  object
#  23  LocationID                 311745 non-null  int64
#  24  TopicID                    311745 non-null  object
#  25  QuestionID                 311745 non-null  object
#  26  ResponseID                 0 non-null       float64
#  27  DataValueTypeID            311745 non-null  object
#  28  StratificationCategoryID1  311745 non-null  object
#  29  StratificationID1          311745 non-null  object
#  30  StratificationCategoryID2  0 non-null       float64
#  31  StratificationID2          0 non-null       float64
#  32  StratificationCategoryID3  0 non-null       float64
#  33  StratificationID3          0 non-null       float64
# dtypes: float64(14), int64(3), object(17)
# memory usage: 80.9+ MB

# %%
# Create a boolean series indicating columns with zero non-null values
empty_column_filter_series = chronic_df.count() == 0 
# Display the boolean series
empty_column_filter_series
# Out:
# YearStart                    False
# YearEnd                      False
# LocationAbbr                 False
# LocationDesc                 False
# DataSource                   False
# Topic                        False
# Question                     False
# Response                      True
# DataValueUnit                False
# DataValueType                False
# DataValue                    False
# DataValueAlt                 False
# DataValueFootnoteSymbol      False
# DataValueFootnote            False
# LowConfidenceLimit           False
# HighConfidenceLimit          False
# StratificationCategory1      False
# Stratification1              False
# StratificationCategory2       True
# Stratification2               True
# StratificationCategory3       True
# Stratification3               True
# Geolocation                  False
# LocationID                   False
# TopicID                      False
# QuestionID                   False
# ResponseID                    True
# DataValueTypeID              False
# StratificationCategoryID1    False
# StratificationID1            False
# StratificationCategoryID2     True
# StratificationID2             True
# StratificationCategoryID3     True
# StratificationID3             True
# dtype: bool

# %%
# Selects the count of non-null values for columns identified as empty by empty_column_filter_series
chronic_df.count()[empty_column_filter_series]
# Out:
# Response                     0
# StratificationCategory2      0
# Stratification2              0
# StratificationCategory3      0
# Stratification3              0
# ResponseID                   0
# StratificationCategoryID2    0
# StratificationID2            0
# StratificationCategoryID3    0
# StratificationID3            0
# dtype: int64

# %%
# Get the names of columns with no data (identified by empty_column_filter_series)
empty_columns = chronic_df.count()[empty_column_filter_series].index
# Display empty_columns variable 
empty_columns
# Out:
# Index(['Response', 'StratificationCategory2', 'Stratification2',
#        'StratificationCategory3', 'Stratification3', 'ResponseID',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
# Remove columns with no data (identified by empty_columns) from the DataFrame chronic_df
# inplace=True ensures the changes are made to chronic_df directly
chronic_df.drop(columns=empty_columns, inplace=True)

# %%
# Print the shape of the DataFrame chronic_df (number of rows, number of columns)
print(chronic_df.shape)
# Print the column names of the DataFrame chronic_df after dropping non-null columns 
chronic_df.columns
# Out:
# (311745, 24)
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DataValueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'Geolocation', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %% [markdown]
# #How has the prevalence of chronic diseases changed from 2015 to 2022, and are there any significant trends or patterns over time?

# %%
# Count occurrences of each year in the "YearStart" column
# We want to see this result to understand the distribution of data over the years
chronic_df["YearStart"].value_counts()
# Out:
# YearStart
# 2019    88823
# 2021    87600
# 2020    67999
# 2022    47125
# 2016     8760
# 2015     8760
# 2018     2678
# Name: count, dtype: int64

# %%
# Count instances of each location abbreviation in the "LocationAbbr" column
chronic_df["LocationAbbr"].value_counts()
# Out:
# LocationAbbr
# US    5809
# TN    5796
# GA    5794
# ND    5794
# MA    5794
# OR    5794
# MI    5794
# MO    5794
# CO    5794
# NY    5794
# CT    5794
# AR    5794
# MS    5794
# VA    5794
# WI    5794
# DE    5794
# NE    5794
# HI    5794
# UT    5794
# LA    5794
# MN    5794
# IL    5794
# DC    5794
# WA    5794
# VT    5794
# ME    5794
# PA    5794
# WY    5794
# NJ    5794
# KS    5794
# AL    5794
# MT    5788
# SD    5786
# NM    5786
# NH    5745
# MD    5745
# FL    5745
# IA    5745
# KY    5745
# WV    5745
# AK    5737
# NC    5696
# RI    5696
# OK    5696
# AZ    5688
# CA    5647
# OH    5647
# IN    5647
# TX    5647
# ID    5647
# NV    5647
# SC    5647
# PR    4212
# VI    4015
# GU    4015
# Name: count, dtype: int64

# %%
# Count instances of each location description grouped by location abbreviation
location_counts = chronic_df.groupby("LocationAbbr")["LocationDesc"].value_counts()
location_counts
# Out:
# LocationAbbr  LocationDesc
# AK            Alaska                  5737
# AL            Alabama                 5794
# AR            Arkansas                5794
# AZ            Arizona                 5688
# CA            California              5647
# CO            Colorado                5794
# CT            Connecticut             5794
# DC            District of Columbia    5794
# DE            Delaware                5794
# FL            Florida                 5745
# GA            Georgia                 5794
# GU            Guam                    4015
# HI            Hawaii                  5794
# IA            Iowa                    5745
# ID            Idaho                   5647
# IL            Illinois                5794
# IN            Indiana                 5647
# KS            Kansas                  5794
# KY            Kentucky                5745
# LA            Louisiana               5794
# MA            Massachusetts           5794
# MD            Maryland                5745
# ME            Maine                   5794
# MI            Michigan                5794
# MN            Minnesota               5794
# MO            Missouri                5794
# MS            Mississippi             5794
# MT            Montana                 5788
# NC            North Carolina          5696
# ND            North Dakota            5794
# NE            Nebraska                5794
# NH            New Hampshire           5745
# NJ            New Jersey              5794
# NM            New Mexico              5786
# NV            Nevada                  5647
# NY            New York                5794
# OH            Ohio                    5647
# OK            Oklahoma                5696
# OR            Oregon                  5794
# PA            Pennsylvania            5794
# PR            Puerto Rico             4212
# RI            Rhode Island            5696
# SC            South Carolina          5647
# SD            South Dakota            5786
# TN            Tennessee               5796
# TX            Texas                   5647
# US            United States           5809
# UT            Utah                    5794
# VA            Virginia                5794
# VI            Virgin Islands          4015
# VT            Vermont                 5794
# WA            Washington              5794
# WI            Wisconsin               5794
# WV            West Virginia           5745
# WY            Wyoming                 5794
# Name: count, dtype: int64

# %%
# Count the number of unique values in each column of chronic_df
chronic_df.nunique()
# Out:
# YearStart                        7
# YearEnd                          4
# LocationAbbr                    55
# LocationDesc                    55
# DataSource                      14
# Topic                           19
# Question                       109
# DataValueUnit                    8
# DataValueType                   12
# DataValue                    14852
# DataValueAlt                 14852
# DataValueFootnoteSymbol          9
# DataValueFootnote                9
# LowConfidenceLimit            8412
# HighConfidenceLimit           8861
# StratificationCategory1          5
# Stratification1                 26
# Geolocation                     54
# LocationID                      55
# TopicID                         19
# QuestionID                     109
# DataValueTypeID                 12
# StratificationCategoryID1        5
# StratificationID1               26
# dtype: int64

# %%
# Sorting our locationAbbr provide a better view to analyse this column 
sorted(chronic_df["LocationAbbr"].unique())
# Out:
# ['AK',
#  'AL',
#  'AR',
#  'AZ',
#  'CA',
#  'CO',
#  'CT',
#  'DC',
#  'DE',
#  'FL',
#  'GA',
#  'GU',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MS',
#  'MT',
#  'NC',
#  'ND',
#  'NE',
#  'NH',
#  'NJ',
#  'NM',
#  'NV',
#  'NY',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'PR',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'US',
#  'UT',
#  'VA',
#  'VI',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY']

# %%
# creating an array with the states without the territories 
states_array = ['AK',
 'AL',
 'AR',
 'AZ',
 'CA',
 'CO',
 'CT',
 'DE',
 'FL',
 'GA',
 'HI',
 'IA',
 'ID',
 'IL',
 'IN',
 'KS',
 'KY',
 'LA',
 'MA',
 'MD',
 'ME',
 'MI',
 'MN',
 'MO',
 'MS',
 'MT',
 'NC',
 'ND',
 'NE',
 'NH',
 'NJ',
 'NM',
 'NV',
 'NY',
 'OH',
 'OK',
 'OR',
 'PA',
 'RI',
 'SC',
 'SD',
 'TN',
 'TX',
 'UT',
 'VA',
 'VT',
 'WA',
 'WI',
 'WV',
 'WY']

# %%
# Filter the DataFrame
us_df = chronic_df[chronic_df["LocationAbbr"].isin(states_array)]
#Displaying dataframe 
us_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 0       2019     2019           GA      Georgia      BRFSS     Disability
# 3       2019     2019           ME        Maine      BRFSS       Diabetes
# 4       2019     2019           NV       Nevada       NVSS  Health Status
# 5       2019     2019           OH         Ohio      BRFSS      Arthritis
# 6       2019     2019           OK     Oklahoma      BRFSS      Arthritis
#
#                      Question DataValueUnit     DataValueType  DataValue  ...  \
# 0  Adults with any disability             %  Crude Prevalence       44.0  ...
# 3       Diabetes among adults             %  Crude Prevalence       11.4  ...
# 4    Life expectancy at birth         Years            Number       78.0  ...
# 5      Arthritis among adults             %  Crude Prevalence       51.8  ...
# 6      Arthritis among adults             %  Crude Prevalence       30.5  ...
#
#    HighConfidenceLimit StratificationCategory1 Stratification1  \
# 0                 47.1                     Age        Age >=65
# 3                 12.7                     Sex            Male
# 4                 78.2                 Overall         Overall
# 5                 53.7                     Age        Age >=65
# 6                 32.3                     Sex          Female
#
#                                       Geolocation  LocationID TopicID  \
# 0    POINT (-83.62758034599966 32.83968109300048)          13     DIS
# 3   POINT (-68.98503133599962 45.254228894000505)          23     DIA
# 4  POINT (-117.07184056399967 39.493240390000494)          32     HEA
# 5    POINT (-82.40426005599966 40.06021014100048)          39     ART
# 6    POINT (-97.52107021399968 35.47203135600046)          40     ART
#
#   QuestionID DataValueTypeID  StratificationCategoryID1 StratificationID1
# 0      DIS01         CRDPREV                        AGE            AGE65P
# 3      DIA01         CRDPREV                        SEX              SEXM
# 4      HEA06            NMBR                    OVERALL               OVR
# 5      ART01         CRDPREV                        AGE            AGE65P
# 6      ART01         CRDPREV                        SEX              SEXF
#
# [5 rows x 24 columns]

# %%
#adding 0 for NaN values in column "DataValue"
us_cleaned_df = us_df.fillna({"DataValue": 0})
us_cleaned_df.head(800)
# Out:
#      YearStart  YearEnd LocationAbbr LocationDesc     DataSource  \
# 0         2019     2019           GA      Georgia          BRFSS
# 3         2019     2019           ME        Maine          BRFSS
# 4         2019     2019           NV       Nevada           NVSS
# 5         2019     2019           OH         Ohio          BRFSS
# 6         2019     2019           OK     Oklahoma          BRFSS
# ..         ...      ...          ...          ...            ...
# 836       2015     2019           MD     Maryland  US Cancer DVT
# 837       2015     2019           KS       Kansas  US Cancer DVT
# 838       2015     2019           FL      Florida  US Cancer DVT
# 839       2015     2019           NM   New Mexico  US Cancer DVT
# 840       2015     2019           WI    Wisconsin  US Cancer DVT
#
#              Topic                                           Question  \
# 0       Disability                         Adults with any disability
# 3         Diabetes                              Diabetes among adults
# 4    Health Status                           Life expectancy at birth
# 5        Arthritis                             Arthritis among adults
# 6        Arthritis                             Arthritis among adults
# ..             ...                                                ...
# 836         Cancer  Breast cancer mortality among all females, und...
# 837         Cancer  Invasive cancer (all sites combined) mortality...
# 838         Cancer  Colon and rectum (colorectal) cancer mortality...
# 839         Cancer  Breast cancer mortality among all females, und...
# 840         Cancer    Invasive cancer (all sites combined), incidence
#
#     DataValueUnit      DataValueType  DataValue  ...  HighConfidenceLimit  \
# 0               %   Crude Prevalence       44.0  ...                 47.1
# 3               %   Crude Prevalence       11.4  ...                 12.7
# 4           Years             Number       78.0  ...                 78.2
# 5               %   Crude Prevalence       51.8  ...                 53.7
# 6               %   Crude Prevalence       30.5  ...                 32.3
# ..            ...                ...        ...  ...                  ...
# 836   per 100,000  Age-adjusted Rate       21.0  ...                 21.7
# 837   per 100,000         Crude Rate      201.5  ...                204.8
# 838   per 100,000  Age-adjusted Rate       15.1  ...                 15.4
# 839        Number             Number       12.0  ...                  NaN
# 840   per 100,000         Crude Rate      568.4  ...                572.3
#
#     StratificationCategory1                                 Stratification1  \
# 0                       Age                                        Age >=65
# 3                       Sex                                            Male
# 4                   Overall                                         Overall
# 5                       Age                                        Age >=65
# 6                       Sex                                          Female
# ..                      ...                                             ...
# 836                     Sex                                          Female
# 837                     Sex                                            Male
# 838                     Sex                                            Male
# 839          Race/Ethnicity  American Indian or Alaska Native, non-Hispanic
# 840                     Sex                                          Female
#
#                                         Geolocation  LocationID TopicID  \
# 0      POINT (-83.62758034599966 32.83968109300048)          13     DIS
# 3     POINT (-68.98503133599962 45.254228894000505)          23     DIA
# 4    POINT (-117.07184056399967 39.493240390000494)          32     HEA
# 5      POINT (-82.40426005599966 40.06021014100048)          39     ART
# 6      POINT (-97.52107021399968 35.47203135600046)          40     ART
# ..                                              ...         ...     ...
# 836    POINT (-76.60926011099963 39.29058096400047)          24     CAN
# 837    POINT (-98.20078122699965 38.34774030000045)          20     CAN
# 838   POINT (-81.92896053899966 28.932040377000476)          12     CAN
# 839   POINT (-106.24058098499967 34.52088095200048)          35     CAN
# 840    POINT (-89.81637074199966 44.39319117400049)          55     CAN
#
#     QuestionID DataValueTypeID  StratificationCategoryID1 StratificationID1
# 0        DIS01         CRDPREV                        AGE            AGE65P
# 3        DIA01         CRDPREV                        SEX              SEXM
# 4        HEA06            NMBR                    OVERALL               OVR
# 5        ART01         CRDPREV                        AGE            AGE65P
# 6        ART01         CRDPREV                        SEX              SEXF
# ..         ...             ...                        ...               ...
# 836      CAN02      AGEADJRATE                        SEX              SEXF
# 837      CAN08         CRDRATE                        SEX              SEXM
# 838      CAN01      AGEADJRATE                        SEX              SEXM
# 839      CAN02            NMBR                       RACE              AIAN
# 840      CAN07         CRDRATE                        SEX              SEXF
#
# [800 rows x 24 columns]

# %%
# Reseting the index for a more aestethic view
us_chronic_df = us_cleaned_df.reset_index(drop=True)
us_chronic_df.head(10)
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource          Topic  \
# 0       2019     2019           GA        Georgia      BRFSS     Disability
# 1       2019     2019           ME          Maine      BRFSS       Diabetes
# 2       2019     2019           NV         Nevada       NVSS  Health Status
# 3       2019     2019           OH           Ohio      BRFSS      Arthritis
# 4       2019     2019           OK       Oklahoma      BRFSS      Arthritis
# 5       2019     2019           WV  West Virginia       NVSS  Health Status
# 6       2020     2020           AL        Alabama      BRFSS       Diabetes
# 7       2020     2020           AK         Alaska      BRFSS     Disability
# 8       2020     2020           IL       Illinois       NVSS         Asthma
# 9       2020     2020           KS         Kansas      BRFSS          Sleep
#
#                                             Question DataValueUnit  \
# 0                         Adults with any disability             %
# 1                              Diabetes among adults             %
# 2                           Life expectancy at birth         Years
# 3                             Arthritis among adults             %
# 4                             Arthritis among adults             %
# 5                           Life expectancy at birth         Years
# 6                              Diabetes among adults             %
# 7                         Adults with any disability             %
# 8  Asthma mortality among all people, underlying ...        Number
# 9                  Short sleep duration among adults             %
#
#       DataValueType  DataValue  ...  HighConfidenceLimit  \
# 0  Crude Prevalence       44.0  ...                 47.1
# 1  Crude Prevalence       11.4  ...                 12.7
# 2            Number       78.0  ...                 78.2
# 3  Crude Prevalence       51.8  ...                 53.7
# 4  Crude Prevalence       30.5  ...                 32.3
# 5            Number       71.9  ...                 72.2
# 6  Crude Prevalence        5.0  ...                  6.8
# 7  Crude Prevalence       20.8  ...                 23.8
# 8            Number       88.0  ...                  NaN
# 9  Crude Prevalence       32.7  ...                 34.5
#
#   StratificationCategory1 Stratification1  \
# 0                     Age        Age >=65
# 1                     Sex            Male
# 2                 Overall         Overall
# 3                     Age        Age >=65
# 4                     Sex          Female
# 5                     Sex            Male
# 6                     Age       Age 18-44
# 7                     Sex            Male
# 8                     Sex          Female
# 9                     Sex            Male
#
#                                       Geolocation  LocationID TopicID  \
# 0    POINT (-83.62758034599966 32.83968109300048)          13     DIS
# 1   POINT (-68.98503133599962 45.254228894000505)          23     DIA
# 2  POINT (-117.07184056399967 39.493240390000494)          32     HEA
# 3    POINT (-82.40426005599966 40.06021014100048)          39     ART
# 4    POINT (-97.52107021399968 35.47203135600046)          40     ART
# 5    POINT (-80.71264013499967 38.66551020200046)          54     HEA
# 6    POINT (-86.63186076199969 32.84057112200048)           1     DIA
# 7   POINT (-147.72205903599973 64.84507995700051)           2     DIS
# 8    POINT (-88.99771017799969 40.48501028300046)          17     AST
# 9    POINT (-98.20078122699965 38.34774030000045)          20    SLEP
#
#   QuestionID DataValueTypeID  StratificationCategoryID1 StratificationID1
# 0      DIS01         CRDPREV                        AGE            AGE65P
# 1      DIA01         CRDPREV                        SEX              SEXM
# 2      HEA06            NMBR                    OVERALL               OVR
# 3      ART01         CRDPREV                        AGE            AGE65P
# 4      ART01         CRDPREV                        SEX              SEXF
# 5      HEA06            NMBR                        SEX              SEXM
# 6      DIA01         CRDPREV                        AGE           AGE1844
# 7      DIS01         CRDPREV                        SEX              SEXM
# 8      AST01            NMBR                        SEX              SEXF
# 9      SLP03         CRDPREV                        SEX              SEXM
#
# [10 rows x 24 columns]

# %%
# Displaying name of columns 
us_chronic_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DataValueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'Geolocation', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
# Dropping empty columns 
us_chronic_df = us_chronic_df.drop(columns=['LocationID','TopicID', 'QuestionID',
       'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'], axis=1)
us_chronic_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 0       2019     2019           GA      Georgia      BRFSS     Disability
# 1       2019     2019           ME        Maine      BRFSS       Diabetes
# 2       2019     2019           NV       Nevada       NVSS  Health Status
# 3       2019     2019           OH         Ohio      BRFSS      Arthritis
# 4       2019     2019           OK     Oklahoma      BRFSS      Arthritis
#
#                      Question DataValueUnit     DataValueType  DataValue  \
# 0  Adults with any disability             %  Crude Prevalence       44.0
# 1       Diabetes among adults             %  Crude Prevalence       11.4
# 2    Life expectancy at birth         Years            Number       78.0
# 3      Arthritis among adults             %  Crude Prevalence       51.8
# 4      Arthritis among adults             %  Crude Prevalence       30.5
#
#    DataValueAlt DataValueFootnoteSymbol DataValueFootnote  LowConfidenceLimit  \
# 0          44.0                     NaN               NaN                41.0
# 1          11.4                     NaN               NaN                10.2
# 2          78.0                     NaN               NaN                77.8
# 3          51.8                     NaN               NaN                49.8
# 4          30.5                     NaN               NaN                28.7
#
#    HighConfidenceLimit StratificationCategory1 Stratification1  \
# 0                 47.1                     Age        Age >=65
# 1                 12.7                     Sex            Male
# 2                 78.2                 Overall         Overall
# 3                 53.7                     Age        Age >=65
# 4                 32.3                     Sex          Female
#
#                                       Geolocation
# 0    POINT (-83.62758034599966 32.83968109300048)
# 1   POINT (-68.98503133599962 45.254228894000505)
# 2  POINT (-117.07184056399967 39.493240390000494)
# 3    POINT (-82.40426005599966 40.06021014100048)
# 4    POINT (-97.52107021399968 35.47203135600046)

# %%
# How has the prevalence of chronic diseases changed from 2015 to 2022,
# and are there any significant trends or patterns over time?

# list all chronic diseases grouped and count them by year.
# example:
# cancer 2018-2018 30
# diabiits 2018 10
# ...
# -----  second version
# diabitis,          2015 , 2016, 2017
# Crude Prevalence   23      12    10
# Crude Rate         10%     15%   10%
#   asma

# %%
#selecting the columns we want to work with 
chronic_per_year =us_chronic_df[["YearStart","LocationDesc","Topic","DataValueType","DataValue"]]
chronic_per_year
# Out:
#         YearStart LocationDesc  \
# 0            2019      Georgia
# 1            2019        Maine
# 2            2019       Nevada
# 3            2019         Ohio
# 4            2019     Oklahoma
# ...           ...          ...
# 287895       2022      Vermont
# 287896       2022     Virginia
# 287897       2022   Washington
# 287898       2022         Utah
# 287899       2022    Wisconsin
#
#                                                   Topic  \
# 0                                            Disability
# 1                                              Diabetes
# 2                                         Health Status
# 3                                             Arthritis
# 4                                             Arthritis
# ...                                                 ...
# 287895                                    Mental Health
# 287896  Nutrition, Physical Activity, and Weight Status
# 287897                                            Sleep
# 287898                                     Immunization
# 287899                                     Immunization
#
#                   DataValueType  DataValue
# 0              Crude Prevalence       44.0
# 1              Crude Prevalence       11.4
# 2                        Number       78.0
# 3              Crude Prevalence       51.8
# 4              Crude Prevalence       30.5
# ...                         ...        ...
# 287895               Crude Mean        7.2
# 287896  Age-adjusted Prevalence       31.6
# 287897         Crude Prevalence       25.3
# 287898         Crude Prevalence        0.0
# 287899  Age-adjusted Prevalence       39.1
#
# [287900 rows x 5 columns]

# %%
#transforming our dataframe with Topic and DataValueType as index and transposing the years into columns 
chronic_pivot_df = chronic_per_year.pivot_table(index=['Topic', 'DataValueType'], columns='YearStart', values='DataValue')
chronic_pivot_df.head(20)
# Out:
# YearStart                                                2015         2016  \
# Topic     DataValueType
# Alcohol   Age-adjusted Prevalence                         NaN          NaN
#           Age-adjusted Rate                               NaN          NaN
#           Crude 75th percentile                           NaN          NaN
#           Crude Median                                    NaN          NaN
#           Crude Prevalence                                NaN          NaN
#           Crude Rate                                      NaN          NaN
#           Number                                          NaN          NaN
#           Per capita alcohol consumption gallons          NaN          NaN
# Arthritis Age-adjusted Prevalence                         NaN          NaN
#           Crude Prevalence                                NaN          NaN
# Asthma    Age-adjusted Prevalence                         NaN          NaN
#           Age-adjusted Rate                               NaN          NaN
#           Crude Prevalence                                NaN          NaN
#           Crude Rate                                      NaN          NaN
#           Number                                          NaN          NaN
# Cancer    Age-adjusted Prevalence                         NaN          NaN
#           Age-adjusted Rate                         85.877000    81.541464
#           Crude Prevalence                                NaN          NaN
#           Crude Rate                                91.371429    88.418643
#           Number                                  2788.878571  2721.044286
#
# YearStart                                         2018        2019  \
# Topic     DataValueType
# Alcohol   Age-adjusted Prevalence                  NaN   12.125800
#           Age-adjusted Rate                        NaN    8.062000
#           Crude 75th percentile                    NaN    3.537752
#           Crude Median                             NaN    2.107923
#           Crude Prevalence                         NaN   13.230683
#           Crude Rate                               NaN   11.533692
#           Number                                   NaN  271.016923
#           Per capita alcohol consumption gallons   NaN    2.468000
# Arthritis Age-adjusted Prevalence                  NaN   19.563486
#           Crude Prevalence                         NaN   22.525614
# Asthma    Age-adjusted Prevalence                  NaN    7.367800
#           Age-adjusted Rate                        NaN    0.362600
#           Crude Prevalence                         NaN    7.662500
#           Crude Rate                               NaN    0.511077
#           Number                                   NaN   18.849231
# Cancer    Age-adjusted Prevalence                  NaN         NaN
#           Age-adjusted Rate                        NaN         NaN
#           Crude Prevalence                         NaN         NaN
#           Crude Rate                               NaN         NaN
#           Number                                   NaN         NaN
#
# YearStart                                               2020        2021  \
# Topic     DataValueType
# Alcohol   Age-adjusted Prevalence                  11.746600   11.650000
#           Age-adjusted Rate                        10.815400   12.772000
#           Crude 75th percentile                     3.568450    3.493876
#           Crude Median                              2.137692    2.119077
#           Crude Prevalence                         11.639846   11.149756
#           Crude Rate                               14.414769   16.569385
#           Number                                  315.876923  346.243077
#           Per capita alcohol consumption gallons    2.545400    2.586000
# Arthritis Age-adjusted Prevalence                        NaN   18.810800
#           Crude Prevalence                               NaN   21.618773
# Asthma    Age-adjusted Prevalence                   7.867400    8.250200
#           Age-adjusted Rate                         0.443800    0.351200
#           Crude Prevalence                          7.946167    8.333167
#           Crude Rate                                0.593538    0.464462
#           Number                                   22.467692   18.616923
# Cancer    Age-adjusted Prevalence                  38.132308         NaN
#           Age-adjusted Rate                              NaN         NaN
#           Crude Prevalence                         39.440308         NaN
#           Crude Rate                                     NaN         NaN
#           Number                                         NaN         NaN
#
# YearStart                                              2022
# Topic     DataValueType
# Alcohol   Age-adjusted Prevalence                 12.939800
#           Age-adjusted Rate                             NaN
#           Crude 75th percentile                    3.762481
#           Crude Median                             2.307846
#           Crude Prevalence                        12.651385
#           Crude Rate                                    NaN
#           Number                                        NaN
#           Per capita alcohol consumption gallons        NaN
# Arthritis Age-adjusted Prevalence                 33.104200
#           Crude Prevalence                        36.373538
# Asthma    Age-adjusted Prevalence                  7.888800
#           Age-adjusted Rate                             NaN
#           Crude Prevalence                         8.235385
#           Crude Rate                                    NaN
#           Number                                        NaN
# Cancer    Age-adjusted Prevalence                 31.426000
#           Age-adjusted Rate                             NaN
#           Crude Prevalence                        32.829222
#           Crude Rate                                    NaN
#           Number                                        NaN

# %%
# Adding 0 to the Nan Values in the years columns 
chronic_pivot_df.fillna(0, inplace=True)
chronic_pivot_df.head(15)
# Out:
# YearStart                                         2015  2016  2018  \
# Topic     DataValueType
# Alcohol   Age-adjusted Prevalence                  0.0   0.0   0.0
#           Age-adjusted Rate                        0.0   0.0   0.0
#           Crude 75th percentile                    0.0   0.0   0.0
#           Crude Median                             0.0   0.0   0.0
#           Crude Prevalence                         0.0   0.0   0.0
#           Crude Rate                               0.0   0.0   0.0
#           Number                                   0.0   0.0   0.0
#           Per capita alcohol consumption gallons   0.0   0.0   0.0
# Arthritis Age-adjusted Prevalence                  0.0   0.0   0.0
#           Crude Prevalence                         0.0   0.0   0.0
# Asthma    Age-adjusted Prevalence                  0.0   0.0   0.0
#           Age-adjusted Rate                        0.0   0.0   0.0
#           Crude Prevalence                         0.0   0.0   0.0
#           Crude Rate                               0.0   0.0   0.0
#           Number                                   0.0   0.0   0.0
#
# YearStart                                               2019        2020  \
# Topic     DataValueType
# Alcohol   Age-adjusted Prevalence                  12.125800   11.746600
#           Age-adjusted Rate                         8.062000   10.815400
#           Crude 75th percentile                     3.537752    3.568450
#           Crude Median                              2.107923    2.137692
#           Crude Prevalence                         13.230683   11.639846
#           Crude Rate                               11.533692   14.414769
#           Number                                  271.016923  315.876923
#           Per capita alcohol consumption gallons    2.468000    2.545400
# Arthritis Age-adjusted Prevalence                  19.563486    0.000000
#           Crude Prevalence                         22.525614    0.000000
# Asthma    Age-adjusted Prevalence                   7.367800    7.867400
#           Age-adjusted Rate                         0.362600    0.443800
#           Crude Prevalence                          7.662500    7.946167
#           Crude Rate                                0.511077    0.593538
#           Number                                   18.849231   22.467692
#
# YearStart                                               2021       2022
# Topic     DataValueType
# Alcohol   Age-adjusted Prevalence                  11.650000  12.939800
#           Age-adjusted Rate                        12.772000   0.000000
#           Crude 75th percentile                     3.493876   3.762481
#           Crude Median                              2.119077   2.307846
#           Crude Prevalence                         11.149756  12.651385
#           Crude Rate                               16.569385   0.000000
#           Number                                  346.243077   0.000000
#           Per capita alcohol consumption gallons    2.586000   0.000000
# Arthritis Age-adjusted Prevalence                  18.810800  33.104200
#           Crude Prevalence                         21.618773  36.373538
# Asthma    Age-adjusted Prevalence                   8.250200   7.888800
#           Age-adjusted Rate                         0.351200   0.000000
#           Crude Prevalence                          8.333167   8.235385
#           Crude Rate                                0.464462   0.000000
#           Number                                   18.616923   0.000000

# %%
# Filter the DataFrame for 'Crude Rate' data value type
crude_rate_df = chronic_pivot_df.xs('Crude Rate', level='DataValueType')

# Plotting
# Plotting
crude_rate_df.T.plot(figsize=(12, 8), marker='o', linewidth=2)  # Plotting transposed DataFrame with marker style 'o' and linewidth 2

plt.title('Prevalence of Chronic Diseases (Crude Rate) Over Time')  # Setting title of the plot
plt.xlabel('Year')  # Setting label for x-axis
plt.ylabel('Crude Rate')  # Setting label for y-axis
plt.xticks(rotation=45)  # Rotating x-axis labels by 45 degrees
plt.legend(title='Chronic Diseases', bbox_to_anchor=(1.05, 1), loc='upper left')  # Adding legend with title and adjusting position
plt.grid(True)  # Adding gridlines to the plot
plt.tight_layout()  # Adjusting layout to prevent overlapping elements
plt.show()  # Displaying the plot

# %%
#Filtering by crude rate, data value type
chronic_cleaned = chronic_pivot_df.loc[(slice(None), "Crude Rate"), :]
#Displaying dataframe
chronic_cleaned
# Out:
# YearStart                                                 2015       2016  \
# Topic                                 DataValueType
# Alcohol                               Crude Rate      0.000000   0.000000
# Asthma                                Crude Rate      0.000000   0.000000
# Cancer                                Crude Rate     91.371429  88.418643
# Cardiovascular Disease                Crude Rate      0.000000   0.000000
# Chronic Obstructive Pulmonary Disease Crude Rate      0.000000   0.000000
# Diabetes                              Crude Rate      0.000000   0.000000
#
# YearStart                                            2018       2019  \
# Topic                                 DataValueType
# Alcohol                               Crude Rate      0.0  11.533692
# Asthma                                Crude Rate      0.0   0.511077
# Cancer                                Crude Rate      0.0   0.000000
# Cardiovascular Disease                Crude Rate      0.0  91.525196
# Chronic Obstructive Pulmonary Disease Crude Rate      0.0  88.514840
# Diabetes                              Crude Rate      0.0  42.505154
#
# YearStart                                                 2020       2021  \
# Topic                                 DataValueType
# Alcohol                               Crude Rate     14.414769  16.569385
# Asthma                                Crude Rate      0.593538   0.464462
# Cancer                                Crude Rate      0.000000   0.000000
# Cardiovascular Disease                Crude Rate     94.651196  95.565370
# Chronic Obstructive Pulmonary Disease Crude Rate     90.214545  88.814445
# Diabetes                              Crude Rate     59.136000  60.504000
#
# YearStart                                            2022
# Topic                                 DataValueType
# Alcohol                               Crude Rate      0.0
# Asthma                                Crude Rate      0.0
# Cancer                                Crude Rate      0.0
# Cardiovascular Disease                Crude Rate      0.0
# Chronic Obstructive Pulmonary Disease Crude Rate      0.0
# Diabetes                              Crude Rate      0.0

# %%
cleaned_index = chronic_per_year.loc[(chronic_per_year["DataValueType"] == "Crude Rate"),:]


cleaned_index_df = cleaned_index.reset_index(drop=True)
cleaned_index.head(10)

# Filter data to incidents that caused Property or Contents Loss
# loss_df = fires_cleaned_df.loc[(fires_cleaned_df["Property Loss"] > 0) |
#                                (fires_cleaned_df["Contents Loss"] > 0) , :]
# loss_df.head()
# Out:
#     YearStart    LocationDesc   Topic DataValueType  DataValue
# 33       2015        Colorado  Cancer    Crude Rate        0.0
# 35       2016           Idaho  Cancer    Crude Rate        0.0
# 38       2015           Texas  Cancer    Crude Rate      234.0
# 39       2015  North Carolina  Cancer    Crude Rate        0.0
# 41       2016       Louisiana  Cancer    Crude Rate       44.4
# 42       2016     Mississippi  Cancer    Crude Rate      653.0
# 44       2015        Virginia  Cancer    Crude Rate      497.3
# 46       2015       Wisconsin  Cancer    Crude Rate       25.2
# 47       2015        New York  Cancer    Crude Rate        2.0
# 50       2015        New York  Cancer    Crude Rate      345.5

# %%
# Generate a bar plot showing the total number of rows (Data Value/Topic) for each chronic disease using pyplot.
# Calculate the total number of rows for each chronic disease

# Filter the DataFrame for 'Crude Rate' data value type
# crude_rate_df = chronic_pivot_df.xs('Crude Rate', level='DataValueType')

datavalue_topic = cleaned_index_df['Topic'].value_counts()

plt.bar(datavalue_topic.index, datavalue_topic.values)

# Create a bar plot using pyplot
plt.xlabel('Topic')
plt.ylabel('DataValue')
plt.title('Data Value per Topic')
plt.xticks(rotation=90)
plt.figure(figsize=(50,40))
plt.tight_layout()
custom_y_ticks = [0, 5000, 10000, 15000, 20000, 25000, 30000, 35000]  # Define your custom y ticks
plt.yticks(custom_y_ticks)
plt.ylim(0, max(custom_y_ticks)+5000)
plt.tight_layout()
plt.show()

# %%
year_start_array = us_chronic_df["YearStart"]
year_start_array
# Out:
# 0         2019
# 1         2019
# 2         2019
# 3         2019
# 4         2019
#           ...
# 287895    2022
# 287896    2022
# 287897    2022
# 287898    2022
# 287899    2022
# Name: YearStart, Length: 287900, dtype: int64

# %%
year_end_array = us_chronic_df["YearEnd"]
year_end_array
# Out:
# 0         2019
# 1         2019
# 2         2019
# 3         2019
# 4         2019
#           ...
# 287895    2022
# 287896    2022
# 287897    2022
# 287898    2022
# 287899    2022
# Name: YearEnd, Length: 287900, dtype: int64

# %%
year_range_dict = {"YearStart": year_start_array,
                   "YearEnd": year_end_array}
year_range_dict
# Out:
# {'YearStart': 0         2019
#  1         2019
#  2         2019
#  3         2019
#  4         2019
#            ...
#  287895    2022
#  287896    2022
#  287897    2022
#  287898    2022
#  287899    2022
#  Name: YearStart, Length: 287900, dtype: int64,
#  'YearEnd': 0         2019
#  1         2019
#  2         2019
#  3         2019
#  4         2019
#            ...
#  287895    2022
#  287896    2022
#  287897    2022
#  287898    2022
#  287899    2022
#  Name: YearEnd, Length: 287900, dtype: int64}
